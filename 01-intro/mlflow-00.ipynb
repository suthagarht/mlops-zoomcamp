# %%
# !mkflow ui
# Out:
# /bin/bash: line 1: mkflow: command not found

# %%
# !mlflow ui
# Out:
# Backend store URI not provided. Using sqlite:///mlflow.db
# Registry store URI not provided. Using backend store URI.
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.schemas
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.tables
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.types
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.constraints
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.defaults
# 2026/02/18 16:10:51 INFO alembic.runtime.plugins: setup plugin alembic.autogenerate.comments
# 2026/02/18 16:10:51 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/02/18 16:10:51 INFO mlflow.store.db.utils: Updating database tables
# 2026/02/18 16:10:51 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# ...
